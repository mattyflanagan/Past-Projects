# %%
 pip install pyne2001
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyne2001: filename=pyne2001-0.1.3-py3-none-any.whl size=93471 sha256=2b3be53e677aaf7e1364398ccf88caf177f8abc5aa3a2909c85d8a05b5b240e2
#   Stored in directory: /root/.cache/pip/wheels/a8/97/8e/2dc1eb19e8463b10513cc143fc30ccad8b37c4988b31acc7c2
# Successfully built pyne2001
# ...

# %%
import pyne2001

pyne2001.test()
# Out:
# ..............
# ----------------------------------------------------------------------
# Ran 14 tests in 1.783s
#
# OK

# %%
pyne2001.get_galactic_dm(39.6,45)
# Out:
# 31.7407

# %%
pyne2001.get_galactic_dm(39.6,55)
# Out:
# 25.5997

# %%
import numpy as np
import matplotlib.pyplot as plt

dist = 0.0001,0.5,0.99,1,1.01,1.5,2,2.5,5,7.5,10,12.5,15,17.5,20,22.5,25,27.5,30,35,40,50
d = 0
dm = []

for d in dist:
  dm.append(pyne2001.get_dm(39.6,45,d))

print(dm)



plt.plot(dist,dm)
plt.ylabel("Dispersion Measure(kpc cm^-3)")
plt.xlabel("Distance(kpc)")
plt.title("Distance v Dispersion Measure for Galactic Co-Ordinates (39.6,45)")
plt.show()
# Out:
# [0.0005, 2.13, 12.5803, 12.7996, 13.017, 21.4566, 26.4256, 29.0684, 31.6651, 31.7387, 31.7407, 31.7407, 31.7407, 31.7407, 31.7407, 31.7407, 31.7407, 31.7407, 31.7407, 31.7407, 31.7407, 31.7407]

# %%
import numpy as np
import matplotlib.pyplot as plt

dist = 0.0001,0.5,0.99,1,1.01,1.5,2,2.5,5,7.5,10,12.5,15,17.5,20,22.5,25,27.5,30,35,40,50
d = 0
dm = []

for d in dist:
  dm.append(pyne2001.get_dm(39.6,55,d))

print(dm)



plt.plot(dist,dm)
plt.ylabel("Dispersion Measure(kpc cm^-3)")
plt.xlabel("Distance(kpc)")
plt.title("Distance v Dispersion Measure for Galactic Co-Ordinates (39.6,55)")
plt.show()

#ALL OTHER WORK FOR THIS ASSIGNMENT WAS COMPLETED BY HAND
# Out:
# [0.0005, 3.18, 12.1205, 12.3074, 12.4923, 19.2413, 22.7077, 24.3162, 25.5796, 25.5994, 25.5997, 25.5997, 25.5997, 25.5997, 25.5997, 25.5997, 25.5997, 25.5997, 25.5997, 25.5997, 25.5997, 25.5997]
